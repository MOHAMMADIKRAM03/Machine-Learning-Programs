# %%
# !pip install numpy pandas matplotlib seaborn scikit-learn
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
Plant_1_Generation_Data = pd.read_csv( r"C:\Users\ASUS\Downloads\Plant_1_Generation_Data.csv\Plant_1_Generation_Data.csv")
Plant_1_Weather_Sensor_Data = pd.read_csv( r"C:\Users\ASUS\Downloads\Plant_1_Weather_Sensor_Data.csv")
Plant_2_Generation_Data = pd.read_csv( r"C:\Users\ASUS\Downloads\Plant_2_Generation_Data.csv\Plant_2_Generation_Data.csv")
Plant_2_Weather_Sensor_Data = pd.read_csv( r"C:\Users\ASUS\Downloads\Plant_2_Weather_Sensor_Data.csv")

# %%
Plant_1_Generation_Data.head()
# Out:
#           DATE_TIME  PLANT_ID       SOURCE_KEY  DC_POWER  AC_POWER  \
# 0  15-05-2020 00:00   4135001  1BY6WEcLGh8j5v7       0.0       0.0
# 1  15-05-2020 00:00   4135001  1IF53ai7Xc0U56Y       0.0       0.0
# 2  15-05-2020 00:00   4135001  3PZuoBAID5Wc2HD       0.0       0.0
# 3  15-05-2020 00:00   4135001  7JYdWkrLSPkdwr4       0.0       0.0
# 4  15-05-2020 00:00   4135001  McdE0feGgRqW7Ca       0.0       0.0
#
#    DAILY_YIELD  TOTAL_YIELD
# 0          0.0    6259559.0
# 1          0.0    6183645.0
# 2          0.0    6987759.0
# 3          0.0    7602960.0
# 4          0.0    7158964.0

# %%
Plant_2_Generation_Data.head()
# Out:
#              DATE_TIME  PLANT_ID       SOURCE_KEY  DC_POWER  AC_POWER  \
# 0  2020-05-15 00:00:00   4136001  4UPUqMRk7TRMgml       0.0       0.0
# 1  2020-05-15 00:00:00   4136001  81aHJ1q11NBPMrL       0.0       0.0
# 2  2020-05-15 00:00:00   4136001  9kRcWv60rDACzjR       0.0       0.0
# 3  2020-05-15 00:00:00   4136001  Et9kgGMDl729KT4       0.0       0.0
# 4  2020-05-15 00:00:00   4136001  IQ2d7wF4YD8zU1Q       0.0       0.0
#
#    DAILY_YIELD   TOTAL_YIELD
# 0  9425.000000  2.429011e+06
# 1     0.000000  1.215279e+09
# 2  3075.333333  2.247720e+09
# 3   269.933333  1.704250e+06
# 4  3177.000000  1.994153e+07

# %%
Plant_2_Generation_Data.shape
# Out:
# (67698, 7)

# %%
Plant_1_Generation_Data.shape
# Out:
# (68778, 7)

# %%
Plant_2_Generation_Data.describe()
# Out:
#         PLANT_ID      DC_POWER      AC_POWER   DAILY_YIELD   TOTAL_YIELD
# count    67698.0  67698.000000  67698.000000  67698.000000  6.769800e+04
# mean   4136001.0    246.701961    241.277825   3294.890295  6.589448e+08
# std          0.0    370.569597    362.112118   2919.448386  7.296678e+08
# min    4136001.0      0.000000      0.000000      0.000000  0.000000e+00
# 25%    4136001.0      0.000000      0.000000    272.750000  1.996494e+07
# 50%    4136001.0      0.000000      0.000000   2911.000000  2.826276e+08
# 75%    4136001.0    446.591667    438.215000   5534.000000  1.348495e+09
# max    4136001.0   1420.933333   1385.420000   9873.000000  2.247916e+09

# %%
Plant_1_Generation_Data.describe()
# Out:
#         PLANT_ID      DC_POWER      AC_POWER   DAILY_YIELD   TOTAL_YIELD
# count    68778.0  68778.000000  68778.000000  68778.000000  6.877800e+04
# mean   4135001.0   3147.426211    307.802752   3295.968737  6.978712e+06
# std          0.0   4036.457169    394.396439   3145.178309  4.162720e+05
# min    4135001.0      0.000000      0.000000      0.000000  6.183645e+06
# 25%    4135001.0      0.000000      0.000000      0.000000  6.512003e+06
# 50%    4135001.0    429.000000     41.493750   2658.714286  7.146685e+06
# 75%    4135001.0   6366.964286    623.618750   6274.000000  7.268706e+06
# max    4135001.0  14471.125000   1410.950000   9163.000000  7.846821e+06

# %%
Plant_1_Weather_Sensor_Data.describe()
# Out:
#         PLANT_ID  AMBIENT_TEMPERATURE  MODULE_TEMPERATURE  IRRADIATION
# count     3182.0          3182.000000         3182.000000  3182.000000
# mean   4135001.0            25.531606           31.091015     0.228313
# std          0.0             3.354856           12.261222     0.300836
# min    4135001.0            20.398505           18.140415     0.000000
# 25%    4135001.0            22.705182           21.090553     0.000000
# 50%    4135001.0            24.613814           24.618060     0.024653
# 75%    4135001.0            27.920532           41.307840     0.449588
# max    4135001.0            35.252486           65.545714     1.221652

# %%
Plant_2_Weather_Sensor_Data.describe()
# Out:
#         PLANT_ID  AMBIENT_TEMPERATURE  MODULE_TEMPERATURE  IRRADIATION
# count     3259.0          3259.000000         3259.000000  3259.000000
# mean   4136001.0            28.069400           32.772408     0.232737
# std          0.0             4.061556           11.344034     0.312693
# min    4136001.0            20.942385           20.265123     0.000000
# 25%    4136001.0            24.602135           23.716881     0.000000
# 50%    4136001.0            26.981263           27.534606     0.019040
# 75%    4136001.0            31.056757           40.480653     0.438717
# max    4136001.0            39.181638           66.635953     1.098766

# %%
Plant_1_Weather_Sensor_Data.isnull().sum()
# Out:
# DATE_TIME              0
# PLANT_ID               0
# SOURCE_KEY             0
# AMBIENT_TEMPERATURE    0
# MODULE_TEMPERATURE     0
# IRRADIATION            0
# dtype: int64

# %%
Plant_2_Weather_Sensor_Data.isnull().sum()
# Out:
# DATE_TIME              0
# PLANT_ID               0
# SOURCE_KEY             0
# AMBIENT_TEMPERATURE    0
# MODULE_TEMPERATURE     0
# IRRADIATION            0
# dtype: int64

# %%
Plant_1_Generation_Data['SOURCE_KEY'].unique()
# Out:
# array(['1BY6WEcLGh8j5v7', '1IF53ai7Xc0U56Y', '3PZuoBAID5Wc2HD',
#        '7JYdWkrLSPkdwr4', 'McdE0feGgRqW7Ca', 'VHMLBKoKgIrUVDU',
#        'WRmjgnKYAwPKWDb', 'ZnxXDlPa8U1GXgE', 'ZoEaEvLYb1n2sOq',
#        'adLQvlD726eNBSB', 'bvBOhCH3iADSZry', 'iCRJl6heRkivqQ3',
#        'ih0vzX44oOqAx2f', 'pkci93gMrogZuBj', 'rGa61gmuvPhdLxV',
#        'sjndEbLyjtCKgGv', 'uHbuxQJl8lW7ozc', 'wCURE6d3bPkepu2',
#        'z9Y9gH1T5YWrNuG', 'zBIq5rxdHJRwDNY', 'zVJPv84UY57bAof',
#        'YxYtjZvoooNbGkE'], dtype=object)

# %%
Plant_2_Generation_Data['SOURCE_KEY'].unique()
# Out:
# array(['4UPUqMRk7TRMgml', '81aHJ1q11NBPMrL', '9kRcWv60rDACzjR',
#        'Et9kgGMDl729KT4', 'IQ2d7wF4YD8zU1Q', 'LYwnQax7tkwH5Cb',
#        'LlT2YUhhzqhg5Sw', 'Mx2yZCDsyf6DPfv', 'NgDl19wMapZy17u',
#        'PeE6FRyGXUgsRhN', 'Qf4GUc1pJu5T6c6', 'Quc1TzYxW2pYoWX',
#        'V94E5Ben1TlhnDV', 'WcxssY2VbP4hApt', 'mqwcsP2rE7J0TFp',
#        'oZ35aAeoifZaQzV', 'oZZkBaNadn6DNKz', 'q49J1IKaHRwDQnt',
#        'rrq4fwE8jgrTyWY', 'vOuJvMaM2sgwLmb', 'xMbIugepa2P7lBB',
#        'xoJJ8DcxJEcupym'], dtype=object)

# %%
len(Plant_1_Generation_Data['SOURCE_KEY'].unique())
# Out:
# 22

# %%
Plant_2_Weather_Sensor_Data['SOURCE_KEY'].unique()
# Out:
# array(['iq8k7ZNt4Mwm3w0'], dtype=object)

# %%
Plant_2_Generation_Data['PLANT_ID'].unique()
# Out:
# array([4136001])

# %%
Plant_2_Weather_Sensor_Data['PLANT_ID'].unique()
# Out:
# array([4136001])

# %%
import pandas as pd
Plant_1_Generation_Data = pd.read_csv( r"C:\Users\ASUS\Downloads\Plant_1_Generation_Data.csv\Plant_1_Generation_Data.csv")
Plant_1_Weather_Sensor_Data = pd.read_csv( r"C:\Users\ASUS\Downloads\Plant_1_Weather_Sensor_Data.csv")
Plant_2_Generation_Data = pd.read_csv( r"C:\Users\ASUS\Downloads\Plant_2_Generation_Data.csv\Plant_2_Generation_Data.csv")
Plant_2_Weather_Sensor_Data = pd.read_csv( r"C:\Users\ASUS\Downloads\Plant_2_Weather_Sensor_Data.csv")
Plant_2_Generation_Data_time_grp = Plant_2_Generation_Data.groupby(['DATE_TIME']).sum()
Plant_2_Generation_Data_time_grp
# Out:
#                      PLANT_ID  \
# DATE_TIME
# 2020-05-15 00:00:00  90992022
# 2020-05-15 00:15:00  90992022
# 2020-05-15 00:30:00  90992022
# 2020-05-15 00:45:00  90992022
# 2020-05-15 01:00:00  90992022
# ...                       ...
# 2020-06-17 22:45:00  90992022
# 2020-06-17 23:00:00  90992022
# 2020-06-17 23:15:00  90992022
# 2020-06-17 23:30:00  90992022
# 2020-06-17 23:45:00  90992022
#
#                                                             SOURCE_KEY  \
# DATE_TIME
# 2020-05-15 00:00:00  4UPUqMRk7TRMgml81aHJ1q11NBPMrL9kRcWv60rDACzjRE...
# 2020-05-15 00:15:00  4UPUqMRk7TRMgml81aHJ1q11NBPMrL9kRcWv60rDACzjRE...
# 2020-05-15 00:30:00  4UPUqMRk7TRMgml81aHJ1q11NBPMrL9kRcWv60rDACzjRE...
# 2020-05-15 00:45:00  4UPUqMRk7TRMgml81aHJ1q11NBPMrL9kRcWv60rDACzjRE...
# 2020-05-15 01:00:00  4UPUqMRk7TRMgml81aHJ1q11NBPMrL9kRcWv60rDACzjRE...
# ...                                                                ...
# 2020-06-17 22:45:00  4UPUqMRk7TRMgml81aHJ1q11NBPMrL9kRcWv60rDACzjRE...
# ...

# %%
Plant_2_Generation_Data_time_grp['DAILY_YIELD'].plot(figsize=(20,5))
plt.title('Total 34 day Plant-2 Yield with time of the day')
plt.ylabel('Yield in kWHr')
# Out:
# Text(0, 0.5, 'Yield in kWHr')

# %%
p2_dc_pwr = Plant_2_Generation_Data.copy()
p2_dc_pwr = p2_dc_pwr.groupby(['DATE_TIME', 'SOURCE_KEY'])['DC_POWER'].mean().unstack()

# Plotting
fig, ax = plt.subplots(ncols=3, nrows=1, dpi=200, figsize=(20, 5))
ax[0].set_title('DC Power Generation to 1st 7 Inverters')
ax[1].set_title('DC Power Generation to next 8 Inverters')
ax[2].set_title('DC Power Generation to last 7 Inverters')
ax[0].set_ylabel('DC POWER in kW')

p2_dc_pwr.iloc[:, 0:7].plot(ax=ax[0], linewidth=5)
p2_dc_pwr.iloc[:, 7:15].plot(ax=ax[1], linewidth=5)
p2_dc_pwr.iloc[:, 15:22].plot(ax=ax[2], linewidth=5)

plt.show()
